# %% [markdown]
# # Jev-based Protein Binder Classification

# %%
from datasets import load_dataset
from simple_jev import *

# %%
## Get Anthropic Claude Protein Binder Design Dataset
ds_df = load_dataset("Anthropic/claude-protein-binder-design", "design_summary", split="full").to_pandas()

## Remove unnecessary columns
cols_to_keep = [
    "uuid",
    "target",
    "binder_length",
    # "sequence",
    "generator",
    "sequence_design_method",
    # "ipsae_min_boltz2",
    # "sc_dockq_boltz2",
    "epitope_n_residues",
    "twist_binding"
]
ds_df = ds_df[cols_to_keep]

## Drop rows with missing values
ds_df = ds_df.dropna()
ds_df = ds_df.rename(columns={"twist_binding": "y_true"})

## Filter to rows where y_true is "non_binder" or "binder"
ds_df = ds_df[ds_df["y_true"].isin(["non_binder", "binder"])]

ds_df.head()
# Out:
#                                    uuid  target  binder_length     generator  \
# 0  816028de-2070-58fc-855d-889401037a4e  BBF-14             80  RFdiffusion3
# 1  1d5855c0-9c16-5c16-b81c-76eec408e06a  BBF-14             80  RFdiffusion3
# 2  8e55f8bf-e0d3-549d-a335-af4b1ee836fc  BBF-14             80  RFdiffusion3
# 3  990a6d64-7947-5775-ac23-3724d3c6f619  BBF-14             90      PXDesign
# 4  4b0b89de-de8c-5458-bef3-037fab717959  BBF-14             80  RFdiffusion3
#
#   sequence_design_method  epitope_n_residues      y_true
# 0            SolubleMPNN                  19  non_binder
# 1            SolubleMPNN                  16  non_binder
# 2            SolubleMPNN                  16  non_binder
# 3            SolubleMPNN                  16  non_binder
# 4            SolubleMPNN                  14  non_binder

# %%
icp_df = load_dataset("Anthropic/claude-protein-binder-design", "insilico_cofold_predictions", split="full").to_pandas()

## Filter to boltz2 for cofolding_model
icp_df = icp_df[icp_df["cofolding_model"] == "boltz2"]

## Columns to keep
cols_to_keep = ['uuid', 'sc_dockq', 'dockq_fnat', 'dockq_irms',
       'dockq_lrms', 'ipsae_min', 'ipsae_max', 'ipsae_binder_to_target',
       'ipsae_target_to_binder', 'iptm_pae', 'ptm_pae', 'lis', 'plddt_binder',
       'plddt_target', 'pae_interface_mean', 'pae_interface_min',
       'n_interface_contacts']
icp_df = icp_df[cols_to_keep]

## Group by UUID and calculate the min, max, mean, std dev, and median
icp_grouped = icp_df.groupby('uuid').agg(['min', 'max', 'mean', 'std', 'median'])

## Flatten the multi-level columns
icp_grouped.columns = ['_'.join(col).strip() for col in icp_grouped.columns.values]

icp_grouped.head()
# Out:
#                                       sc_dockq_min  sc_dockq_max  \
# uuid
# 002a7326-6f58-51e3-95c8-67d38c8269fd       0.00422       0.01264
# 002e2495-ef2a-56d4-8f2a-45ca6d32c5e0       0.11532       0.32867
# 00422e01-3e64-5260-8b9a-a4f7422baa47       0.43040       0.71994
# 008df55d-b575-52b3-83ee-85f2ce3ba893       0.72404       0.80501
# 00ce26f9-b738-5425-bb38-8e2526005b3b           NaN           NaN
#
#                                       sc_dockq_mean  sc_dockq_std  \
# uuid
# 002a7326-6f58-51e3-95c8-67d38c8269fd       0.005978      0.002958
# 002e2495-ef2a-56d4-8f2a-45ca6d32c5e0       0.241634      0.112821
# 00422e01-3e64-5260-8b9a-a4f7422baa47       0.560169      0.130252
# 008df55d-b575-52b3-83ee-85f2ce3ba893       0.757012      0.033211
# 00ce26f9-b738-5425-bb38-8e2526005b3b            NaN           NaN
#
#                                       sc_dockq_median  dockq_fnat_min  \
# uuid
# 002a7326-6f58-51e3-95c8-67d38c8269f
# uuid
# 002a7326-6f58-51e3-95c8-67d38c8269fd                 15.302868
# 002e2495-ef2a-56d4-8f2a-45ca6d32c5e0                 11.371016
# 00422e01-3e64-5260-8b9a-a4f7422baa47                  1.407463
# 008df55d-b575-52b3-83ee-85f2ce3ba893                  2.588436
# 00ce26f9-b738-5425-bb38-8e2526005b3b                  1.788854
#
#                                       n_interface_contacts_median
# uuid
# 002a7326-6f58-51e3-95c8-67d38c8269fd                         44.5
# 002e2495-ef2a-56d4-8f2a-45ca6d32c5e0                         46.0
# 00422e01-3e64-5260-8b9a-a4f7422baa47                         26.0
# 008df55d-b575-52b3-83ee-85f2ce3ba893                         52.0
# 00ce26f9-b738-5425-bb38-8e2526005b3b                         26.0
#
# [5 rows x 80 columns]

# %%
## Join ICP Grouped DataFrame with Anthropic Claude Protein Binder Design Dataset
df = icp_grouped.merge(ds_df, on="uuid", how="inner")

## Remove any NA
df = df.dropna()

df.head()
# Out:
#                                    uuid  sc_dockq_min  sc_dockq_max  \
# 0  002a7326-6f58-51e3-95c8-67d38c8269fd       0.00422       0.01264
# 1  002e2495-ef2a-56d4-8f2a-45ca6d32c5e0       0.11532       0.32867
# 2  008df55d-b575-52b3-83ee-85f2ce3ba893       0.72404       0.80501
# 4  015e2121-bbb8-5aa0-9b08-bb74b51f0e46       0.26097       0.50225
# 5  01b73ae2-3c77-5380-83c5-83c8df8c511d       0.01297       0.42022
#
#    sc_dockq_mean  sc_dockq_std  sc_dockq_median  dockq_fnat_min  \
# 0       0.005978      0.002958         0.004700         0.00000
# 1       0.241634      0.112821         0.321010         0.30000
# 2       0.757012      0.033211         0.756130         0.77273
# 4       0.362534      0.065558         0.364210         0.08333
# 5       0.152985      0.155114         0.128685         0.00000
#
#    dockq_fnat_max  dockq_fnat_mean  dockq_fnat_std  ...  \
# 0         0.00000         0.000000        0.000000  ...
# 1         0.31111         0.302222        0.004969  ...
# 2         0.90909         0.836366        0.060983  ...
# 4         0.33333         0.189744        0.071974  ...
# 5         0.66667         0.322224        0.341266  ...
#
#    n_interface_contacts_max  n_interface_contacts_mean  \
# 0                        78                       49.8
# 1                        55                       43.4
# 2                        54                       51.2
# 4                        55                       49.3
# 5                        39                       29.8
#
#    n_interface_contacts_std  n_interface_contacts_median  target  \
# 0                 15.302868                         44.5    Cas9
# 1                 11.371016                         46.0    EGFR
# 2                  2.588436                         52.0  BBF-14
# 4                  5.121849                         51.0    TNFa
# 5                  9.295160                         33.0    RBX1
#
#    binder_length                  generator  sequence_design_method  \
# 0             70  FreeBindCraft (BindCraft)             SolubleMPNN
# 1             90          Proteina-Complexa             SolubleMPNN
# 2             89                   BoltzGen             SolubleMPNN
# 4            102               RFdiffusion3             SolubleMPNN
# 5             83               RFdiffusion3  Caliby (SolubleCaliby)
#
#    epitope_n_residues      y_true
# 0                  36  non_binder
# 1                  35  non_binder
# 2                  22  non_binder
# 4                  22  non_binder
# 5                  22  non_binder
#
# [5 rows x 87 columns]

# %%
print(f"Candidates to test: {len(df)}")
print(f"Non-binders: {len(df[df['y_true'] == 'non_binder'])}")
print(f"Binders: {len(df[df['y_true'] == 'binder'])}")
# Out:
# Candidates to test: 1097
# Non-binders: 813
# Binders: 284

# %%
## Try one API call

# import requests

# payload = build_request(df.iloc[0], model="featherless-ai/Qwen3.8-27B-classifier")
# payload

# ## Call the API with the built request
# api_url = "https://simple-jev-demo-api.featherless.ai/v1/classifier"

# try:
#     response = requests.post(api_url, json=payload, timeout=45)
#     response.raise_for_status()
#     print(response.json())
# except requests.HTTPError:
#     print(f"HTTP error {response.status_code}: {response.text}")
# except requests.RequestException as exc:
#     print(f"Request failed: {exc}")

# %%
## The public demo is rate-limited (4 req/s); take an evenly stratified sample.
## For the full labeled set, drop `sample_size` or set it to len(df).
# SEED = 1337
# sample_size = 100  # or any desired sample size

# class_counts = df["y_true"].value_counts()
# n_per_class = min(sample_size // 2, class_counts["non_binder"], class_counts["binder"])
# n = 2 * n_per_class
# sample_df = (
#     df.groupby("y_true", group_keys=False)
#     .sample(n=n_per_class, random_state=SEED)
#     .sample(frac=1, random_state=SEED)
#     .reset_index(drop=True)
# )

# print(sample_df["y_true"].value_counts())

# %%
# print(f"\nScoring {n} designs against Simple Jev's demo API ({DEFAULT_DEMO_MODEL}) ...")

# scored_df = classify_dataframe(sample_df)

# %%
## Score full dataset
print(f"\nScoring {len(df)} designs against Simple Jev's demo API ({DEFAULT_DEMO_MODEL}) ...")

scored_df = classify_dataframe(df)
# Out:
# Scoring 1097 designs against Simple Jev's demo API (featherless-ai/Qwen3.6-35B-A3B-classifier) ...
#   scored 25/1097
#   scored 50/1097
#   scored 75/1097
#   scored 100/1097
#   scored 125/1097
#   scored 150/1097
#   scored 175/1097
#   scored 200/1097
#   scored 225/1097
#   scored 250/1097
#   scored 275/1097
#   scored 300/1097
#   scored 325/1097
#   scored 350/1097
#   scored 375/1097
#   scored 400/1097
#   scored 425/1097
#   scored 450/1097
#   scored 475/1097
#   scored 500/1097
#   scored 525/1097
#   scored 550/1097
#   scored 575/1097
#   scored 600/1097
#   scored 625/1097
#   scored 650/1097
#   scored 675/1097
#   scored 700/1097
#   scored 725/1097
#   scored 750/1097
#   scored 775/1097
#   scored 800/1097
#   scored 825/1097
#   scored 850/1097
#   scored 875/1097
#   scored 900/1097
#   scored 925/1097
#   scored 950/1097
#   scored 975/1097
#   scored 1000/1097
#   scored 1025/1097
#   scored 1050/1097
#   scored 1075/1097
#   scored 1097/1097

# %%
scored_df.head()
# Out:
#                                    uuid  sc_dockq_min  sc_dockq_max  \
# 0  002a7326-6f58-51e3-95c8-67d38c8269fd       0.00422       0.01264
# 1  002e2495-ef2a-56d4-8f2a-45ca6d32c5e0       0.11532       0.32867
# 2  008df55d-b575-52b3-83ee-85f2ce3ba893       0.72404       0.80501
# 3  015e2121-bbb8-5aa0-9b08-bb74b51f0e46       0.26097       0.50225
# 4  01b73ae2-3c77-5380-83c5-83c8df8c511d       0.01297       0.42022
#
#    sc_dockq_mean  sc_dockq_std  sc_dockq_median  dockq_fnat_min  \
# 0       0.005978      0.002958         0.004700         0.00000
# 1       0.241634      0.112821         0.321010         0.30000
# 2       0.757012      0.033211         0.756130         0.77273
# 3       0.362534      0.065558         0.364210         0.08333
# 4       0.152985      0.155114         0.128685         0.00000
#
#    dockq_fnat_max  dockq_fnat_mean  dockq_fnat_std  ...  \
# 0         0.00000         0.000000        0.000000  ...
# 1         0.31111         0.302222        0.004969  ...
# 2         0.90909         0.836366        0.060983  ...
# 3         0.33333         0.189744        0.071974  ...
# 4         0.66667         0.322224        0.341266  ...
#
#    n_interface_contacts_std  n_interface_contacts_median  target  \
# 0                 15.302868                         44.5    Cas9
# 1                 11.371016                         46.0    EGFR
# 2                  2.588436                         52.0  BBF-14
# 3                  5.121849                         51.0    TNFa
# 4                  9.295160                         33.0    RBX1
#
#    binder_length                  generator  sequence_design_method  \
# 0             70  FreeBindCraft (BindCraft)             SolubleMPNN
# 1             90          Proteina-Complexa             SolubleMPNN
# 2             89                   BoltzGen             SolubleMPNN
# 3            102               RFdiffusion3             SolubleMPNN
# 4             83               RFdiffusion3  Caliby (SolubleCaliby)
#
#    epitope_n_residues      y_true  p_binder      y_pred
# 0                  36  non_binder  0.356724  non_binder
# 1                  35  non_binder  0.955684      binder
# 2                  22  non_binder  0.985931      binder
# 3                  22  non_binder  0.956716      binder
# 4                  22  non_binder  0.932939      binder
#
# [5 rows x 89 columns]

# %%
scored_df.to_csv("scored_df_twist.csv", index=False)

# %%
evaluate(scored_df)
# Out:
# n scored: 1097
# class balance (true binder rate): 0.259
# majority-class baseline accuracy: 0.741
# Simple Jev accuracy:              0.350
# Simple Jev ROC-AUC (P binder):    0.648
#
# confusion matrix [rows=true, cols=pred], order=[non_binder, binder]:
# [[108 705]
#  [  8 276]]
#
#               precision    recall  f1-score   support
#
#   non_binder       0.93      0.13      0.23       813
#       binder       0.28      0.97      0.44       284
#
#     accuracy                           0.35      1097
#    macro avg       0.61      0.55      0.33      1097
# weighted avg       0.76      0.35      0.29      1097
#
# per-target accuracy:
#              mean  count
# target
# TNFa     0.114504    131
# MBP      0.116279     86
# TrkA     0.166667     90
# BBF-14   0.215909     88
# EGFR     0.231707     82
# Nipah-G  0.253731     67
# BHRF1    0.292308     65
# 15-PGDH  0.300000     30
# PD-L1    0.448718     78
# IL-7Ra   0.468354     79
# RBX1     0.487805     82
# VEGF-A   0.551282     78
# Cas9     0.629032     62
# TREM2    0.848101     79

# %%
## Scatterplots colored by true binder class
import matplotlib.pyplot as plt

CLASS_COLORS = {"non_binder": "tab:grey", "binder": "tab:red"}
CLASS_ALPHAS = {"non_binder": 0.3, "binder": 1}

def plot_by_true_class(x_column: str) -> None:
    fig, ax = plt.subplots()
    for label, group in scored_df.groupby("y_true"):
        ax.scatter(
            group[x_column],
            group["p_binder"],
            color=CLASS_COLORS[label],
            alpha=CLASS_ALPHAS[label],
            label=label,
        )
    ax.set(xlabel=x_column, ylabel="p(binder)")
    ax.legend(title="Twist Binder Classification")
    plt.show()


plot_by_true_class("ipsae_min_min")
plot_by_true_class("ipsae_min_max")
plot_by_true_class("ipsae_max_max")
plot_by_true_class("ipsae_min_mean")
plot_by_true_class("sc_dockq_min")
plot_by_true_class("sc_dockq_max")
plot_by_true_class("sc_dockq_mean")
